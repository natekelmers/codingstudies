# %%
# 
import pprint as pp
import datetime as dt
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium import webdriver
import requests
import os

# %% [markdown]
# def init_browser():
#     # @NOTE: Replace the path with your actual path to the chromedriver
#     executable_path = {"executable_path": "chromedriver"}
#     return Browser("chrome", **executable_path, headless=False)

# %% [markdown]
# def scrape():
#     browser = init_browser()
#     listings = {}
#
#     url = ""
#     browser.visit(url)
#     time.sleep(1)
#
#     html = browser.html
#     soup = BeautifulSoup(html, "html.parser")
#
#     listings["****************"] = soup.find("****************", class_="****************").get_text()
#     listings["****************"] = soup.find("****************", class_="****************").get_text()
#     listings["****************"] = soup.find("****************", class_="****************").get_text()
#
#     return listings

# %%
url = "https://mars.nasa.gov/news/?page="
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
session = requests.Session()
session.headers.update({'User-Agent': 'Custom user agent'})
response = requests.get(url)

# %%
browser.visit(url)

# %%
nasa_url_prfx = "https://mars.nasa.gov"  ## when I noticed the link was a relative reference.
navigation_url_h = "https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&year="
navigation_url_t = "%3Apublish_date&category=19%2C165%2C184%2C204&blank_scope=Latest"
article_title=[]
article_url=[]
article_teaser=[]

# %%
year_start = 2000
date_ = dt.datetime.now()
max_year = date_.year
browser.visit(navigation_url_h+str(year_start)+navigation_url_t)
while year_start <= max_year:
    nasa = browser.html
    soup = BeautifulSoup(nasa, "html.parser")
    div = soup.find_all("div", {"class":"content_title"})
    tsr = soup.find_all("div", {"class":"article_teaser_body"})
    for a in div:
        article_title.append(a.text)
        article_url.append(nasa_url_prfx+str(a.a["href"]))
    for c in tsr:
        article_teaser.append(c)

    year_start=year_start+1
    browser.visit(navigation_url_h+str(year_start)+navigation_url_t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-799331a49fec> in <module>()
#       1 year_start = 2000
# ----> 2 date_ = dt.datetime.now()
#       3 max_year = date_.year
#       4 browser.visit(navigation_url_h+str(year_start)+navigation_url_t)
#       5 while year_start <= max_year:
#
# NameError: name 'dt' is not defined

# %%
test = pd.DataFrame(np.column_stack([article_title,article_url]),columns=["title","url"])

# %%
#test.to_csv("test.csv")
soup = BeautifulSoup(nasa, "html.parser")
div_section = soup.find_all("div", {"class":"content_title"})

# %%
len(article_teaser)
# Out:
# 241

# %%
links = []
div_section = soup.find_all("div", {"class":"content_title"})

# %%
test
# Out:
#                                                  title  \
# 0    "2001 Mars Odyssey" for NASA'S Next Trip to th...
# 1    \n\nNASA Briefing on First Mission to Study Ma...
# 2    \n\nNew 'AR' Mobile App Features 3-D NASA Spac...
# 3    \n\nWitness First Mars Launch from West Coast\n\n
# 4    \n\nDemonstration Proves Nuclear Fission Syste...
# 5        \n\nNASA Invests in Visionary Technology \n\n
# 6     \n\nNASA is Ready to Study the Heart of Mars\n\n
# 7    \n\nNASA Briefing on First Mission to Study Ma...
# 8    \n\nNew 'AR' Mobile App Features 3-D NASA Spac...
# 9    \n\nWitness First Mars Launch from West Coast\n\n
# 10   \n\nDemonstration Proves Nuclear Fission Syste...
# 11       \n\nNASA Invests in Visionary Technology \n\n
# 12    \n\nNASA is Ready to Study the Heart of Mars\n\n
# 13   Project Scientist for the Mars Exploration Rov...
# 14   Mars Odyssey Mission Status, Thursday, Decembe...
# 15              Researchers Toy with New Rover Designs
# 16           All-Terrain Rovers May Scale Mars' Cliffs
# 17   Ulysses Gets A New Partner In The Hunt For The...
# 18                             The First Sulfur Eaters
# 19                             If Santa Were a Martian
# 20   Mars Odyssey Mission Status, Friday, November ...
# 21   Analyses show water stayed on Mars longer than...
# 22                             Machinists to the Stars
# 23   Mars Odyssey Mission Status, Tuesday, November...
# 24         NASA Selects 10 Investigations for 2005 MRO
# 25   "Porkchop" is the First Menu Item on a Trip to...
# 26   Mars Odyssey's First Look at Mars Is All Treat...
# 27   Mars Odyssey Mission Status, Tuesday, October ...
# 28            Odyssey Healthy and in Orbit Around Mars
# 29                             The USA Returns to Mars
# ..                                                 ...
# 439  \n\nNASA Briefing on First Mission to Study Ma...
# 440  \n\nNew 'AR' Mobile App Features 3-D NASA Spac...
# 441  \n\nWitness First Mars Launch from West Coast\n\n
# 442  \n\nDemonstration Proves Nuclear Fission Syste...
# 443      \n\nNASA Invests in Visionary Technology \n\n
# 444   \n\nNASA is Ready to Study the Heart of Mars\n\n
# 445  \n\nNASA Briefing on First Mission to Study Ma...
# 446  \n\nNew 'AR' Mobile App Features 3-D NASA Spac...
# 447  \n\nWitness First Mars Launch from West Coast\n\n
# 448  \n\nDemonstration Proves Nuclear Fission Syste...
# 449      \n\nNASA Invests in Visionary Technology \n\n
# 450   \n\nNASA is Ready to Study the Heart of Mars\n\n
# 451  \n\nNASA Briefing on First Mission to Study Ma...
# 452  \n\nNew 'AR' Mobile App Features 3-D NASA Spac...
# 453  \n\nWitness First Mars Launch from West Coast\n\n
# 454  \n\nDemonstration Proves Nuclear Fission Syste...
# 455      \n\nNASA Invests in Visionary Technology \n\n
# 456   \n\nNASA is Ready to Study the Heart of Mars\n\n
# 457  \n\nNASA Briefing on First Mission to Study Ma...
# 458  \n\nNew 'AR' Mobile App Features 3-D NASA Spac...
# 459  \n\nWitness First Mars Launch from West Coast\n\n
# 460  \n\nDemonstration Proves Nuclear Fission Syste...
# 461      \n\nNASA Invests in Visionary Technology \n\n
# 462   \n\nNASA is Ready to Study the Heart of Mars\n\n
# 463  \n\nNASA Briefing on First Mission to Study Ma...
# 464  \n\nNew 'AR' Mobile App Features 3-D NASA Spac...
# 465  \n\nWitness First Mars Launch from West Coast\n\n
# 466  \n\nDemonstration Proves Nuclear Fission Syste...
# 467      \n\nNASA Invests in Visionary Technology \n\n
# 468   \n\nNASA is Ready to Study the Heart of Mars\n\n
#
#                                                    url
# 0    https://mars.nasa.gov/news/389/2001-mars-odyss...
# 1    https://mars.nasa.gov/news/8322/nasa-briefing-...
# 2    https://mars.nasa.gov/news/8321/new-ar-mobile-...
# 3    https://mars.nasa.gov/news/8317/witness-first-...
# 4    https://mars.nasa.gov/news/8340/demonstration-...
# 5    https://mars.nasa.gov/news/8326/nasa-invests-i...
# 6    https://mars.nasa.gov/news/8325/nasa-is-ready-...
# 7    https://mars.nasa.gov/news/8322/nasa-briefing-...
# 8    https://mars.nasa.gov/news/8321/new-ar-mobile-...
# 9    https://mars.nasa.gov/news/8317/witness-first-...
# 10   https://mars.nasa.gov/news/8340/demonstration-...
